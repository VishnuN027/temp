# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('HR_records.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate       Department  \
# 0   48       Yes         Non-Travel      403.0  Human Resources
# 1   40        No      Travel_Rarely     1433.0  Human Resources
# 2   22        No  Travel_Frequently     1259.0          Support
# 3   24        No         Non-Travel     1218.0         Software
# 4   41        No      Travel_Rarely      987.0         Software
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                30          5             Other              1
# 1                46          3  Technical Degree              1
# 2                45          1         Marketing              1
# 3                 8          3   Human Resources              1
# 4                43          3           Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                       2.0            80
# 1               2  ...                       2.0            80
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       5000 non-null   int64
#  1   Attrition                 5000 non-null   object
#  2   BusinessTravel            4991 non-null   object
#  3   DailyRate                 4996 non-null   float64
#  4   Department                4989 non-null   object
#  5   DistanceFromHome          5000 non-null   int64
#  6   Education                 5000 non-null   int64
#  7   EducationField            4995 non-null   object
#  8   EmployeeCount             5000 non-null   int64
#  9   EmployeeNumber            5000 non-null   int64
#  10  EnvironmentSatisfaction   5000 non-null   int64
#  11  Gender                    4996 non-null   object
#  12  HourlyRate                4999 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Age                          0
# Attrition                    0
# BusinessTravel               9
# DailyRate                    4
# Department                  11
# DistanceFromHome             0
# Education                    0
# EducationField               5
# EmployeeCount                0
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                       4
# HourlyRate                   1
# JobInvolvement               1
# JobLevel                     0
# JobRole                      8
# JobSatisfaction              0
# MaritalStatus               12
# MonthlyIncome               11
# MonthlyRate                  2
# NumCompaniesWorked           1
# Over18                       1
# OverTime                     0
# PercentSalaryHike            1
# PerformanceRating            0
# RelationshipSatisfaction     2
# StandardHours                0
# StockOptionLevel             0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 73

# %%
# Deleting the entire row contains missing values

# %%
df = df.dropna(axis=0)
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe(include='all').transpose()
# Out:
#                            count unique                top  freq  \
# Age                       4945.0    NaN                NaN   NaN
# Attrition                   4945      2                 No  2476
# BusinessTravel              4945      3  Travel_Frequently  1682
# DailyRate                 4945.0    NaN                NaN   NaN
# Department                  4945      6              Sales   857
# DistanceFromHome          4945.0    NaN                NaN   NaN
# Education                 4945.0    NaN                NaN   NaN
# EducationField              4945      6          Marketing   854
# EmployeeCount             4945.0    NaN                NaN   NaN
# EmployeeNumber            4945.0    NaN                NaN   NaN
# EnvironmentSatisfaction   4945.0    NaN                NaN   NaN
# Gender                      4945      2             Female  2510
# HourlyRate                4945.0    NaN                NaN   NaN
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df = df[['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]

# %%
plt.rcParams["figure.figsize"] = (20, 20)
df.hist(bins=20)
plt.show()

# %% [markdown]
# # AGE DISTIBUTION

# %%
plt.figure(figsize=(15,10), dpi=80)
sns.histplot(data=df, x='Age', bins=42, kde=True).set_title('Age Distribution of Employee');

# %% [markdown]
# # Attrition by age

# %%
plt.figure(figsize=(14,6), dpi=80)
sns.countplot(data=df, x='Age', hue='Attrition', order = df['Age'].value_counts().index, palette='seismic_r').set_title('Attrition by Age');

# %% [markdown]
# # Attrition by Gender

# %%
plt.figure(figsize=(8,5), dpi=80)
sns.countplot(data=df, x='Gender', hue='Attrition', order = df['Gender'].value_counts().index, palette='seismic_r').set_title('Attrition by Gender');

# %% [markdown]
# # Attrition by Department

# %%
plt.figure(figsize=(8,5), dpi=80)
sns.countplot(data=df[(df['Attrition'] == 'Yes')], x='Department', palette='cubehelix', order = df['Department']
              .value_counts().index).set_title('Attrition by Department');

# %%
plt.figure(figsize=(8,5), dpi=80)
sns.countplot(data=df[(df['Attrition'] == 'Yes')], x='Education', palette='cubehelix', order = df['Education']
              .value_counts().index).set_title('Attrition by Department');

# %%
plt.figure(figsize=(8,5), dpi=80)
sns.countplot(data=df[(df['Attrition'] == 'Yes')], x='MonthlyIncome', palette='cubehelix', order = df['MonthlyIncome']
              .value_counts().index).set_title('Attrition by Department');

# %% [markdown]
# # atition by MaritalStatus

# %%
plt.figure(figsize=(8,5), dpi=80)
.countplot(data=df, x='MaritalStatus', hue='Attrition', order = df['MaritalStatus'].value_counts().index, palette='seismic_r').set_title('Attrition by Gender');

# %% [raw]
# Attrition by Education Field

# %%
plt.figure(figsize=(11,6), dpi=80)
sns.histplot(data=df, x='EducationField').set_title('Attrition by Education Field');

# %%
plt.figure(figsize=(15,10), dpi=80)
sns.histplot(data=df, x='YearsAtCompany', bins=42, kde=True).set_title('YearsAtCompany Distribution of Employee');

# %% [markdown]
# # employee Distribution of Years In CurrentRole

# %%
plt.figure(figsize=(15,10), dpi=80)
sns.histplot(data=df, x='YearsInCurrentRole', bins=42, kde=True).set_title('employee Distribution of YearsInCurrentRole');

# %% [markdown]
# # Numer of Companies Worked

# %%
plt.figure(figsize=(15,10), dpi=80)
sns.histplot(data=df, x='NumCompaniesWorked', bins=42, kde=True).set_title(' Numer of Companies Worked');

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.barplot(y = 'JobRole',x = 'MonthlyIncome',hue = 'Gender',data = df,ax = ax)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='JobRole'>
