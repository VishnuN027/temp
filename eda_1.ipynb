# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('HR_records.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate       Department  \
# 0   48       Yes         Non-Travel      403.0  Human Resources
# 1   40        No      Travel_Rarely     1433.0  Human Resources
# 2   22        No  Travel_Frequently     1259.0          Support
# 3   24        No         Non-Travel     1218.0         Software
# 4   41        No      Travel_Rarely      987.0         Software
#
#    DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                30          5             Other              1
# 1                46          3  Technical Degree              1
# 2                45          1         Marketing              1
# 3                 8          3   Human Resources              1
# 4                43          3           Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                       2.0            80
# 1               2  ...                       2.0            80
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       5000 non-null   int64
#  1   Attrition                 5000 non-null   object
#  2   BusinessTravel            4991 non-null   object
#  3   DailyRate                 4996 non-null   float64
#  4   Department                4989 non-null   object
#  5   DistanceFromHome          5000 non-null   int64
#  6   Education                 5000 non-null   int64
#  7   EducationField            4995 non-null   object
#  8   EmployeeCount             5000 non-null   int64
#  9   EmployeeNumber            5000 non-null   int64
#  10  EnvironmentSatisfaction   5000 non-null   int64
#  11  Gender                    4996 non-null   object
#  12  HourlyRate                4999 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Age                          0
# Attrition                    0
# BusinessTravel               9
# DailyRate                    4
# Department                  11
# DistanceFromHome             0
# Education                    0
# EducationField               5
# EmployeeCount                0
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                       4
# HourlyRate                   1
# JobInvolvement               1
# JobLevel                     0
# JobRole                      8
# JobSatisfaction              0
# MaritalStatus               12
# MonthlyIncome               11
# MonthlyRate                  2
# NumCompaniesWorked           1
# Over18                       1
# OverTime                     0
# PercentSalaryHike            1
# PerformanceRating            0
# RelationshipSatisfaction     2
# StandardHours                0
# StockOptionLevel             0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 73

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # EDA

# %%
df.dtypes
# Out:
# Age                           int64
# Attrition                    object
# BusinessTravel               object
# DailyRate                   float64
# Department                   object
# DistanceFromHome              int64
# Education                     int64
# EducationField               object
# EmployeeCount                 int64
# EmployeeNumber                int64
# EnvironmentSatisfaction       int64
# Gender                       object
# HourlyRate                  float64
# JobInvolvement              float64
# JobLevel                      int64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyIncome               float64
# MonthlyRate                 float64
# NumCompaniesWorked          float64
# Over18                       object
# OverTime                     object
# PercentSalaryHike           float64
# PerformanceRating             int64
# RelationshipSatisfaction    float64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
col_dict={}
for i in df.columns:
    col_dict[i]=df[i].nunique()
    print(i," :",df[i].nunique())
# Out:
# Age  : 43
# Attrition  : 2
# BusinessTravel  : 3
# DailyRate  : 1352
# Department  : 6
# DistanceFromHome  : 50
# Education  : 5
# EducationField  : 6
# EmployeeCount  : 1
# EmployeeNumber  : 4945
# EnvironmentSatisfaction  : 4
# Gender  : 2
# HourlyRate  : 171
# JobInvolvement  : 4
# JobLevel  : 5
# JobRole  : 10
# JobSatisfaction  : 4
# MaritalStatus  : 3
# MonthlyIncome  : 4734
# MonthlyRate  : 4915
# NumCompaniesWorked  : 9
# Over18  : 1
# OverTime  : 2
# PercentSalaryHike  : 50
# PerformanceRating  : 4
# RelationshipSatisfaction  : 4
# StandardHours  : 1
# StockOptionLevel  : 4
# TotalWorkingYears  : 40
# TrainingTimesLastYear  : 6
# WorkLifeBalance  : 4
# YearsAtCompany  : 40
# YearsInCurrentRole  : 35
# YearsSinceLastPromotion  : 37
# YearsWithCurrManager  : 38

# %% [markdown]
# # Attrition by MaritalStatus

# %%
plt.figure(figsize=(10,5), dpi=80)
sns.countplot(data=df, x='MaritalStatus', hue='Attrition', order = df['MaritalStatus'].value_counts().index, palette='seismic_r').set_title('Attrition by MaritalStatus');

# %% [markdown]
# # MonthlyIncome and jobrole Distribution

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.barplot(y = 'JobRole',x = 'MonthlyIncome',hue = 'Gender',data = df,ax = ax)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='JobRole'>

# %% [markdown]
# # No.of Companies Worked

# %%
plt.figure(figsize=(15,10), dpi=50)
sns.histplot(data=df, x='NumCompaniesWorked', bins=42, kde=True).set_title(' Numer of Companies Worked');

# %% [markdown]
# # Attition based RelationshipSatisfaction

# %%
sns.countplot(x = 'RelationshipSatisfaction',hue='Attrition', data = df)
plt.title('Attition based RelationshipSatisfaction')
# Out:
# Text(0.5, 1.0, 'Attition based RelationshipSatisfaction')

# %% [markdown]
# # Over18 Pie plot

# %%
Over18=df.Over18.value_counts()
Over18[:].plot.pie(figsize=(10, 10),autopct='%1.2f%%')
plt.title('Over18 Pie plot')
# Out:
# Text(0.5, 1.0, 'Over18 Pie plot')

# %% [markdown]
# # OverTime Pie plot

# %%
overTime=df.OverTime.value_counts()
OverTime[:].plot.pie(figsize=(10,10),autopct='%1.2f%%')
plt.title('OverTime Pie plot')O
# Out:
# Text(0.5, 1.0, 'OverTime Pie plot')

# %% [markdown]
# # Years In CurrentRole

# %%
plt.figure(figsize=(15,10), dpi=80)
sns.histplot(data=df, x='YearsInCurrentRole', bins=42, kde=True).set_title('employee Distribution of YearsInCurrentRole');

# %% [markdown]
# # Work Life Balance Pie plot

# %%
WorkLifeBalance=df.WorkLifeBalance.value_counts()
WorkLifeBalance[:].plot.pie(figsize=(10,10),autopct='%1.2f%%')
plt.title('WorkLifeBalance Pie plot')
# Out:
# Text(0.5, 1.0, 'WorkLifeBalance Pie plot')

# %% [markdown]
# # Attrition and Total Working Years

# %%
plt.figure(figsize=(14,6), dpi=80)
sns.countplot(data=df, x='TotalWorkingYears', hue='Attrition', order = df['TotalWorkingYears'].value_counts().index, palette='seismic_r').set_title('Attrition and TotalWorkingYears');

# %% [markdown]
# # Attrition and Years In Current Role

# %%
plt.figure(figsize=(14,6), dpi=80)
sns.countplot(data=df, x='YearsInCurrentRole', hue='Attrition', order = df['YearsInCurrentRole'].value_counts().index, palette='seismic_r').set_title('Attrition and Years In CurrentRole');

# %% [markdown]
# # employee Distribution of YearsWithCurrManager

# %%
plt.figure(figsize=(15,10), dpi=80)
sns.histplot(data=df, x='YearsWithCurrManager', bins=42, kde=True).set_title('employee Distribution of YearsWithCurrManager');

# %%
YearsWithCurrManager=df.YearsWithCurrManager.value_counts()
YearsWithCurrManager[:].plot.pie(figsize=(1,10),autopct='%1.2f%%')
plt.title('WorkLifeBalance Pie plot')
# Out:
# Text(0.5, 1.0, 'YearsWithCurrManager Pie plot')

# %% [markdown]
# # No.of Companies Worked Pie plot

# %%
NumCompaniesWorked=df.NumCompaniesWorked.value_counts()
NumCompaniesWorked[:].plot.pie(figsize=(10,10),autopct='%1.2f%%')
plt.title('NumCompaniesWorked Pie plot')
# Out:
# Text(0.5, 1.0, 'NumCompaniesWorked Pie plot')

# %%
sns.displot(data=df, x="MonthlyIncome",hue='Attrition',kind="kde")
plt.title('Attition based MonthlyIncome distribution plot')
# Out:
# Text(0.5, 1.0, 'Attition based MonthlyIncome distribution plot')

# %%
sns.displot(data=df, x="MonthlyRate",hue='Attrition',kind="kde")
plt.title('Attition based MonthlyIncome distribution plot')
# Out:
# Text(0.5, 1.0, 'Attition based MonthlyIncome distribution plot')
